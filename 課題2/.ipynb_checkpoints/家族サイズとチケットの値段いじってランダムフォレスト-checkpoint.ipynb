# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("train.csv")
df = df.drop(["PassengerId","Cabin"], axis = 1)
df = df.replace("male",0).replace("female",1).replace("S",0).replace("C",1).replace("Q",2)
df.count()
# Out:
# Survived    891
# Pclass      891
# Name        891
# Sex         891
# Age         714
# SibSp       891
# Parch       891
# Ticket      891
# Fare        891
# Embarked    889
# dtype: int64

# %%
df
y = df["Survived"].as_matrix()

# %%
split_data = []
for survived in [0,1]:
    split_data.append(df[df.Survived==survived])

temp = [i["Age"].dropna() for i in split_data]
plt.hist(temp, histtype="barstacked", bins=20)
# Out:
# ([array([ 13.,   5.,  11.,  16.,  52.,  62.,  55.,  49.,  38.,  28.,  23.,
#           23.,  15.,   9.,   8.,   7.,   4.,   5.,   1.,   0.]),
#   array([ 40.,  14.,  15.,  31.,  79.,  98.,  85.,  84.,  73.,  45.,  35.,
#           35.,  29.,  16.,  13.,  11.,   4.,   5.,   1.,   1.])],
#  array([  0.42 ,   4.399,   8.378,  12.357,  16.336,  20.315,  24.294,
#          28.273,  32.252,  36.231,  40.21 ,  44.189,  48.168,  52.147,
#          56.126,  60.105,  64.084,  68.063,  72.042,  76.021,  80.   ]),
#  <a list of 2 Lists of Patches objects>)

# %%
temp = [i["SibSp"].dropna() for i in split_data]
plt.hist(temp, histtype="barstacked", bins=20,range=[2,8])
# Out:
# ([array([ 15.,   0.,   0.,  12.,   0.,   0.,  15.,   0.,   0.,   0.,   5.,
#            0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   7.]),
#   array([ 28.,   0.,   0.,  16.,   0.,   0.,  18.,   0.,   0.,   0.,   5.,
#            0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   7.])],
#  array([ 2. ,  2.3,  2.6,  2.9,  3.2,  3.5,  3.8,  4.1,  4.4,  4.7,  5. ,
#          5.3,  5.6,  5.9,  6.2,  6.5,  6.8,  7.1,  7.4,  7.7,  8. ]),
#  <a list of 2 Lists of Patches objects>)

# %%
FamilyisBig1 = []
for i in df["SibSp"]:
    if i > 2:
        FamilyisBig1.append(1)
    else:
        FamilyisBig1.append(0)

df['FamilyisBig1'] = np.array(FamilyisBig1)

# %%
temp = [i["Parch"].dropna() for i in split_data]
plt.hist(temp, histtype="barstacked", bins=20,range=[3,6])
# Out:
# ([array([ 2.,  0.,  0.,  0.,  0.,  0.,  4.,  0.,  0.,  0.,  0.,  0.,  0.,
#           4.,  0.,  0.,  0.,  0.,  0.,  1.]),
#   array([ 5.,  0.,  0.,  0.,  0.,  0.,  4.,  0.,  0.,  0.,  0.,  0.,  0.,
#           5.,  0.,  0.,  0.,  0.,  0.,  1.])],
#  array([ 3.  ,  3.15,  3.3 ,  3.45,  3.6 ,  3.75,  3.9 ,  4.05,  4.2 ,
#          4.35,  4.5 ,  4.65,  4.8 ,  4.95,  5.1 ,  5.25,  5.4 ,  5.55,
#          5.7 ,  5.85,  6.  ]),
#  <a list of 2 Lists of Patches objects>)

# %%
FamilyisBig2 = []
for i in df["Parch"]:
    if i > 2:
        FamilyisBig2.append(1)
    else:
        FamilyisBig2.append(0)

df['FamilyisBig2'] = np.array(FamilyisBig2)

# %%
temp = [i["Fare"].dropna() for i in split_data]
plt.hist(temp, histtype="barstacked", bins=20)
# Out:
# ([array([ 402.,   97.,   27.,    9.,    4.,    4.,    0.,    0.,    3.,
#             1.,    2.,    0.,    0.,    0.,    0.,    0.,    0.,    0.,
#             0.,    0.]),
#   array([ 562.,  170.,   67.,   39.,   15.,   16.,    2.,    0.,    9.,
#             2.,    6.,    0.,    0.,    0.,    0.,    0.,    0.,    0.,
#             0.,    3.])],
#  array([   0.     ,   25.61646,   51.23292,   76.84938,  102.46584,
#          128.0823 ,  153.69876,  179.31522,  204.93168,  230.54814,
#          256.1646 ,  281.78106,  307.39752,  333.01398,  358.63044,
#          384.2469 ,  409.86336,  435.47982,  461.09628,  486.71274,
#          512.3292 ]),
#  <a list of 2 Lists of Patches objects>)

# %%
ChicketisCheap = []
for i in df["Fare"]:
    if i < 50:
        ChicketisCheap.append(1)
    else:
        ChicketisCheap.append(0)

df['ChicketisCheap'] = np.array(ChicketisCheap)

# %%
df
# Out:
#      Survived  Pclass                                               Name  Sex  \
# 0           0       3                            Braund, Mr. Owen Harris    0
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1
# 2           1       3                             Heikkinen, Miss. Laina    1
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1
# 4           0       3                           Allen, Mr. William Henry    0
# 5           0       3                                   Moran, Mr. James    0
# 6           0       1                            McCarthy, Mr. Timothy J    0
# 7           0       3                     Palsson, Master. Gosta Leonard    0
# 8           1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    1
# 9           1       2                Nasser, Mrs. Nicholas (Adele Achem)    1
# 10          1       3                    Sandstrom, Miss. Marguerite Rut    1
# ...

# %%
df.count()
# Out:
# Survived          891
# Pclass            891
# Name              891
# Sex               891
# Age               714
# SibSp             891
# Parch             891
# Ticket            891
# Fare              891
# Embarked          889
# FamilyisBig1      891
# FamilyisBig2      891
# ChicketisCheap    891
# dtype: int64

# %%
df1 = df.drop(["Survived","Name","Ticket","Fare","SibSp","Parch"], axis = 1)
df1 = df1.fillna(df1.mean())
X = df1.as_matrix()
df1.count()
# Out:
# Pclass            891
# Sex               891
# Age               891
# Embarked          891
# FamilyisBig1      891
# FamilyisBig2      891
# ChicketisCheap    891
# dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbct = GradientBoostingClassifier(random_state=0, max_depth=3, learning_rate=0.1)
gbct.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=0, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
print('train accuracy: %.3f' % gbct.score(X_train, y_train))
print('test  accuracy: %.3f' % gbct.score(X_test, y_test))
# Out:
# train accuracy: 0.864
# test  accuracy: 0.843

# %%
df2 = pd.read_csv("test.csv")
df2 = df2.drop(["PassengerId","Cabin"], axis = 1)
df2 = df2.replace("male",0).replace("female",1).replace("S",0).replace("C",1).replace("Q",2)

    
FamilyisBig11 = []
for i in df2["SibSp"]:
    if i > 2:
        FamilyisBig11.append(1)
    else:
        FamilyisBig11.append(0)

df2['FamilyisBig1'] = np.array(FamilyisBig11)

FamilyisBig22 = []
for i in df2["Parch"]:
    if i > 2:
        FamilyisBig22.append(1)
    else:
        FamilyisBig22.append(0)

df2['FamilyisBig2'] = np.array(FamilyisBig22)

ChicketisCheap1 = []
for i in df2["Fare"]:
    if i < 50:
        ChicketisCheap1.append(1)
    else:
        ChicketisCheap1.append(0)

df2['ChicketisCheap'] = np.array(ChicketisCheap1)

df2 = df2.drop(["Name","Ticket","Fare","SibSp","Parch"], axis = 1)
df2 = df2.fillna(df2.mean())
X1 = df2.as_matrix()

# %%
y1 = gbct.predict(X1)

# %%
a =[i for i in range(892,1310)]
dfnew2 = pd.DataFrame({'PassengerId':a ,'Survived': y1})
dfnew2.to_csv("pred3.csv")

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(min_samples_leaf=3, random_state=0)
forest.fit(X_train, y_train)
print('Train score: {}'.format(forest.score(X_train, y_train)))
print('Test score: {}'.format(forest.score(X_test, y_test)))
# Out:
# Train score: 0.8488023952095808
# Test score: 0.8340807174887892

# %%
y2 = forest.predict(X1)
a =[i for i in range(892,1310)]
dfnew2 = pd.DataFrame({'PassengerId':a ,'Survived': y2})
dfnew2.to_csv("pred4.csv")

# %%
from sklearn import svm

clf = svm.SVC()
clf.fit(X_train, y_train)
print('train accuracy: %.3f' % clf.score(X_train, y_train))
print('test  accuracy: %.3f' % clf.score(X_test, y_test))
# Out:
# train accuracy: 0.847
# test  accuracy: 0.812
