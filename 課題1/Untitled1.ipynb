# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option("display.max_columns", 30)

# %%
df = pd.read_csv('train.csv')

# %%
df.corr().sort_values(by=["SalePrice"], ascending=False)
# Out:
#               MSSubClass  Neighborhood  OverallQual  YearBuilt  YearRemodAdd  \
# SalePrice       0.476982      0.696882     0.790982   0.619545      0.535370
# OverallQual     0.471136      0.667647     1.000000   0.665203      0.552825
# GrLivArea       0.347673      0.411751     0.593007   0.369635      0.325158
# Neighborhood    0.532233      1.000000     0.667647   0.683095      0.521638
# GarageCars      0.397369      0.585252     0.628715   0.570728      0.433995
# ExterQual       0.393934      0.631870     0.726278   0.638206      0.570870
# KitchenQual     0.391700      0.566358     0.673331   0.575836      0.611669
# BsmtQual        0.423389      0.629227     0.644946   0.707715      0.545541
# GarageArea      0.387789      0.529629     0.562022   0.523139      0.390554
# YearBuilt       0.572252      0.683095     0.665203   1.000000      0.652419
# TotalBsmtSF     0.291599      0.456092     0.537808   0.434021      0.328112
# ...

# %%
X = df2.loc[:,["SalePrice",]]

# %%
y = df["SalePrice"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
import xgboost as xgb
mod = xgb.XGBRegressor()
mod.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=1, gamma=0,
#        learning_rate=0.1, max_delta_step=0, max_depth=3,
#        min_child_weight=1, missing=None, n_estimators=100, nthread=-1,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=1)

# %%
# MSEを出力する関数を読み込む
from sklearn.metrics import mean_squared_error as mse

# RMSEをtrainとtestに分けて出力
# 過学習をしているかどうかを確認
print('RMSE')
print('train: %.3f' % (mse(np.log(y_train), np.log(mod.predict(X_train)) ** 1/2)))
print('test : %.3f' % (mse(np.log(y_test), np.log(mod.predict(X_test)) ** 1/2)))
# Out:
# RMSE
# train: 36.138
# test : 36.201

# %%
# matplotlibをインポート
import matplotlib.pyplot as plt
# Jupyterを利用していたら、以下のおまじないを書くとnotebook上に図が表示
# %matplotlib inline
# 学習用、検証用それぞれで残差をプロット
plt.scatter(y_train, mod.predict(X_train) - y_train, c = 'blue', marker = 'o', label = 'Train Data')
plt.scatter(y_test, mod.predict(X_test) - y_test, c = 'lightgreen', marker = 's', label = 'Test Data')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
# 凡例を左上に表示
plt.legend(loc = 'upper left')
# y = 0に直線を引く
plt.hlines(y = 0, xmin = 0, xmax = 100000, lw = 2, color = 'red')
plt.xlim([0, 800000])
plt.show()
